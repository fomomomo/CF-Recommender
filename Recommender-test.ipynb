# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline
sns.set()

# %%
pd.read_csv('final_products.csv')
# Out:
#                                                   name  \
# 0                cotton leaf Floral Single Blanket 104
# 1    Handloom Hut Polyester Pista (Green) Crush Sol...
# 2    Handloomhub Polyester Pink Floral Eyelet Door ...
# 3    Handloomhub Polyester Light Blue Self Design E...
# 4    Handloomhub Polyester Pink Self Design Eyelet ...
# ..                                                 ...
# 101  TWG Handicraft Mix Polyresin Decorative Ashirw...
# 102  Madhubani Hand Painted Pure Tussar Silk Long D...
# 103                            Silk Embroidery Dupatta
# 104                 Sami Gota Work Bandani silk duppta
# 105  TWG Handicraft Multicolor Meditating Buddha St...
#
#                        category       pid   price  \
# 0     Blankets, Quilts & Dohars  6KO999OS  1999.0
# 1                      Curtains  ENEOISU9  1599.0
# 2                      Curtains  96UAN6BB   799.0
# 3                      Curtains  BK9UNAAA  1499.0
# ...
